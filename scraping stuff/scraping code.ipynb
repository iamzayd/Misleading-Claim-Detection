# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options
import time
import json

option = Options()
option.headless = False

driver = webdriver.Firefox(options=option)
driver.implicitly_wait(5)
baseUrl = "https://youtube.com/"
keyword = "Programming"

def getChannelUrl():
    driver.get(f"{baseUrl}/search?q={keyword}")
    time.sleep(3)
    allChannelList = driver.find_elements(By.CSS_SELECTOR, "#text.style-scope.ytd-channel-name a.yt-simple-endpoint.style-scope.yt-formatted-string")
    links = list(dict.fromkeys(map(lambda a: a.get_attribute("href"), allChannelList)))
    return links

def getChannelDetails(urls):
    details = []
    for url in urls:
        driver.get(f"{url}/about")
        cname = driver.find_element(By.CSS_SELECTOR, "#text.style-scope.ytd-channel-name").text
        cDess = driver.find_element(By.CSS_SELECTOR, "#description-container > yt-formatted-string:nth-child(2)").text
        clink = url
        otherLinkObj = driver.find_elements(By.CSS_SELECTOR, "#link-list-container.style-scope.ytd-channel-about-metadata-renderer a.yt-simple-endpoint.style-scope.ytd-channel-about-metadata-renderer")
        otherLinks = list(dict.fromkeys(map(lambda a: a.get_attribute("href"), otherLinkObj)))

        obj = {
            "cname": cname,
            "curl": clink,
            "cdesc": cDess,
            "otherLinks": otherLinks
        }
        details.append(obj)
    return details

if __name__ == "__main__":
    allChannelUrls = getChannelUrl()
    allChannelDetails = getChannelDetails(allChannelUrls)
    print(json.dumps(allChannelDetails, indent=4))

driver.quit()
# Out:
# C:\Users\Najeeb\AppData\Local\Temp/ipykernel_9912/201063648.py:8: DeprecationWarning: headless property is deprecated, instead use add_argument('-headless')
#   option.headless = False
# [
#     {
#         "cname": "TestGorilla",
#         "curl": "https://www.youtube.com/channel/UC0YiyXX0xhZ27o2F5qawaCA",
#         "cdesc": "TestGorilla can help you as a recruiter or hiring manager to measure your candidates on job skills, personality, and fit. Pre-employment screening with TestGorilla can streamline your hiring process to save you time and give you in-depth insight into your candidates\u2019 skills. \n\nWith TestGorilla\u2019s extensive library of pre-employment screening tests, you can test candidates for job-specific skills such as coding or digital marketing, as well as more general skills like critical thinking. In addition, our personality and culture-add tests help you get to know your applicants as real people, not just pieces of paper.\n\nSimplify your hiring with TestGorilla: https://www.testgorilla.com/\n\nLinkedIn: https://www.linkedin.com/company/testgorilla/\nInstagram: https://www.instagram.com/testgorilla_official/\nFacebook: https://www.facebook.com/testgorilla/",
#         "otherLinks": []
#     },
#     {
#         "cname": "Apna College",
#         "curl": "https://www.youtube.com/@ApnaCollegeOfficial",
#         "cdesc": "I'm Shradha, Ex-Microsoft Software Engineer, DRDO. My journey started from a small village of Haryana, in college I learned coding and got 2 internships at Microsoft, work for DRDO, invited for Google SPS and a Full Time Offer from Microsoft. I believe that skills are more important today and want to help students to learn & crack their dream companies \u2764\ufe0f\nSo, I left my Microsoft Job and started to teach students. I love my students and I love sharing my learnings.\nTo Chalo Phodte hain!\n\n\nFeel free to contact Shradha Didi for Seminars, Hackathons & Collaborations at the given email id below.",
#         "otherLinks": []
#     },
#     {
#         "cname": "FilFar",
#         "curl": "https://www.youtube.com/@FilFar",
#         "cdesc": "Welcome digital artists \u26a1\ufe0f\n\nI am a musician & programmer since 2013. I am creating music for work / concentration / focus / deep mood / productivity... This music is aimed at digital artists who need to isolate themselves from surrounding and want to work in a deeper mood than just silence. \ud83c\udfb6\n\nThis is my work & hobby. I also used to program everything like games/websites/apps/robots... \ud83d\udcdf\nBut there was one problem... I couldn't find a good music to keep me concentrated and focused all the time while programming in rushy environment. So my passion slowly jumped to music and I started learning everything about it. \ud83c\udfb6\n\nOn this channel I am mainly creating content regarding music to boost your skills. \ud83d\udcc8\n\nHonestly I have never planned to run any youtube channel at all. Whole this channel was just hobby before and people simply started to love the content I create, so they decide to make it grow. Thank you all for support my friends. \u2764\ufe0f",
#         "otherLinks": []
#     },
#     {
#         "cname": "Power Couple",
#         "curl": "https://www.youtube.com/@Power_Couple",
#         "cdesc": "On this channel, Sarra (Product Manager, Microsoft) and Sahil (Software Engineer, Google) share their experiences to help you fast-track your career in the tech industry. Subscribe and hit the notification button to stay up-to-date on new content :)\n\nAu revoir!\n\nDISCLAIMER: All opinions shared on this channel are our own and don't express views or opinions of our employers. We only use our experiences and public knowledge to make our content. NO CONFIDENTIAL INFORMATION of our employers is used or shared on this channel. This is not a Professional Coaching channel, it only highlights the public resources that have worked for our careers.",
#         "otherLinks": []
#     },
#     {
#         "cname": "Quick Support",
#         "curl": "https://www.youtube.com/@QuickSupport",
#         "cdesc": "\u0915\u094d\u0935\u093f\u0915 \u0938\u092a\u094b\u0930\u094d\u091f \u091a\u0948\u0928\u0932 \u092e\u0947\u0902 \u0906\u092a\u0915\u093e \u0938\u094d\u0935\u093e\u0917\u0924 \u0939\u0948\u0902 \u0907\u0938 \u091a\u0948\u0928\u0932 \u092e\u0948\u0902 \u0939\u092e \u0906\u092a\u0915\u094b 100% \u0917\u0947\u0930\u0947\u0902\u091f\u0940 \u0926\u0947\u0924\u0947 \u0939\u0948\u0902 \u0915\u0940 \u0939\u092e \u092c\u094b\u0930\u093f\u0902\u0917 \u0935\u093f\u0921\u093f\u092f\u094b \u0905\u092a\u0932\u094b\u0921 \u0928\u0939\u0940\u0902 \u0915\u0930\u0947\u0902\u0917\u0947 \u0914\u0930 \u091c\u093f\u0938 \u091f\u0949\u092a\u093f\u0915 \u0915\u0947 \u092c\u093e\u0930\u0947 \u092e\u0947\u0902 \u092c\u0924\u093e\u092f\u093e \u0917\u092f\u093e \u0939\u094b\u0917\u093e \u0909\u0938\u0915\u0940 \u0939\u0940 \u092c\u093e\u0924 \u0915\u0930\u0947\u0902\u0917\u0947 \u0914\u0930 \u0939\u0930 \u090f\u0915 \u091f\u0949\u092a\u093f\u0915\u094d\u0938 \u0915\u0947 \u0909\u092a\u0930 \u0939\u092e \u092a\u0942\u0930\u0940 \u091c\u093e\u0928\u0915\u093e\u0930\u0940 \u0926\u0947\u0928\u0947 \u0915\u0940 \u0915\u094b\u0936\u093f\u0936 \u0915\u0930\u0947\u0902\u0917\u0947 \u0925\u0948\u0902\u0915\u094d\u0938!\n\nWebsite: https://www.careerhow.org/\nFacebook: https://www.facebook.com/QuickSupportChannel\nTwitter:  https://twitter.com/QS_Channel\nInstagram: https://www.instagram.com/quick_support007\nYoutube: https://www.youtube.com/c/QuickSupport\nLinkedin: https://www.linkedin.com/in/Anil-Nakrani\nChannel Owner: Anil Nakrani",
#         "otherLinks": []
#     },
#     {
#         "cname": "freeCodeCamp.org",
#         "curl": "https://www.youtube.com/@freecodecamp",
#         "cdesc": "Learn to code for free.",
#         "otherLinks": []
#     },
#     {
#         "cname": "Jenny's Lectures CS IT",
#         "curl": "https://www.youtube.com/@JennyslecturesCSIT",
#         "cdesc": "Jenny\u2019s Lectures CS IT is a Free YouTube Channel providing Computer Science / Information Technology / Computer-related tutorials including NET & JRF Coaching Videos, GATE Coaching Videos, UGC NET, NTA NET, JRF, BTech, MTech, Ph.D., tips and other helpful videos for Computer Science / Information Technology students. Teaching Computer Science in Informal Space. ",
#         "otherLinks": []
#     },
#     {
#         "cname": "WIRED",
#         "curl": "https://www.youtube.com/@WIRED",
#         "cdesc": "WIRED is where tomorrow is realized.",
#         "otherLinks": []
#     },
#     {
#         "cname": "Chill Music Lab",
#         "curl": "https://www.youtube.com/@MusicLabChill",
#         "cdesc": "Choose the soundtrack for your most productive self\n\nMusic Lab was created to shed some light on how the music is made, educate and help people on how to navigate the intricacies of popular genres and how they can affect various activities. On this channel, we have a wide variety of playlists suited for all kinds of everyday tasks: work, studies, programming, sports and more. We want to popularize music that will have a beneficial effect on productivity.\n\nWe also collaborate with independent artists and labels within the USA and around the world. Many composers and producers are often unfairly overlooked and we strive to promote such artists by exposing their work to the widest possible audience.\n\nFor collaborations, business inquiries and licensing please contact us via the email below.\n\nDon't forget to check our website: https://musiclab.cloud",
#         "otherLinks": []
#     },
#     {
#         "cname": "Dr. Charansing Kayte",
#         "curl": "https://www.youtube.com/@DrCharansingKayte",
#         "cdesc": "In an age of technology, learning is no longer restricted to lecture halls and textbooks. Videos have now become a frequently used method of teaching, providing students with interactive content that makes learning more fun. On this channel we will provide only Educational, Technological and software training video.",
#         "otherLinks": []
#     },
#     {
#         "cname": "bigboxSWE",
#         "curl": "https://www.youtube.com/@bigboxSWE",
#         "cdesc": "",
#         "otherLinks": []
#     },
#     {
#         "cname": "Nick White",
#         "curl": "https://www.youtube.com/@NickWhite",
#         "cdesc": "Nick White is a YouTuber who focuses on creating both entertaining and educational content. For business email - business@nickwwhite.com\n\nNick's Other Social Media Accounts\n_______________\nTwitter - https://twitter.com/nicholaswwhite\nInstagram - https://instagram.com/nickwwhite\nTwitch - https://twitch.tv/nickwhitettv",
#         "otherLinks": []
#     },
#     {
#         "cname": "Fireship",
#         "curl": "https://www.youtube.com/@Fireship",
#         "cdesc": "High-intensity \u26a1 code tutorials and tech news to help you ship your app faster. New videos every week covering the topics every programmer should know. \n\nThe original home of #100SecondsOfCode #TheCodeReport and #CodeThisNotThat. Created by Jeff Delaney. \n\nBuilding an app? Get project support, advanced full courses, and more at https://fireship.io",
#         "otherLinks": []
#     },
#     {
#         "cname": "Tim Kim",
#         "curl": "https://www.youtube.com/@TimKimMe",
#         "cdesc": "Hey guys,  \ud83d\udc4b I'm Tim Kim, yes... that's my real name.\n\nLast year, after 10+ years of self-learning skills online, I used those skills to build and sell a company. \nInstead of starting another money-making business, I started this channel to try and find a way to learn skills full-time.\n\nI'm going to be breaking down hard skills step-by-step as I learn them myself.\n\nJoin the #TryHard team and subscribe so you can learn how to do cool shiz with me.\n\nIf you want access to all of the resources and tools that I use to learn check out my website:\n\n\ud83d\udc49 http://timkim.me",
#         "otherLinks": []
#     },
#     {
#         "cname": "Lofi boost your mood",
#         "curl": "https://www.youtube.com/@lofiboostyourmood6235",
#         "cdesc": "Wellcome to Lofi Boost Your Mood :\n\ud83e\udd17 I wish everyone who visit my channel the most love, peace and abundance. I wish you get amazing grades. I love you \ud83d\udc9d\n\ud83e\udd17 The chill music is perfect to Calm your anxiety, Learn, read books, paint, work from home, play video games, do your homework, sleep, prepare exams, have a break, cook, or chill drive, simply chill out with your friends. I hope my channel will help you focus on studying and relaxing. \ud83d\udc9d\n\ud83d\udd14 Click the bell to stay updated on the best Mix Chill Lofi HipHop\n\ud83c\udf3fThanks mah friends so much for watching, sharing, commenting and Like!!!\nCOPYRIGHT \u00a9 & FAQ\n\u2022 This video was given a special license directly from the artist's visual.\n\u2022 All music on Lofi boost your mood are copyrighted.\n-----------------\n\u2022 Follow Lofi boost your mood :\n\u2615\ufe0f Subscribe: https://www.youtube.com/channel/UCESVcUXbcDOrJ293_KWotyQ?sub_confirmation=1\n\u2615\ufe0f Fanpage: https://www.facebook.com/mimilofichillmix\n\ud83d\udc8c Business contact: contact@lofichillmix.com",
#         "otherLinks": []
#     },
#     {
#         "cname": "Internet Made Coder",
#         "curl": "https://www.youtube.com/@InternetMadeCoder",
#         "cdesc": "I make videos about learning to code.\n\nLearning coding changed my life - I hope to help you learn it and change yours too.\n\n\ud83d\ude80 Land $100K Python Programming Job - https://academy.internetmadecoder.com/python-dev-masterclass\n\n\ud83d\ude80 Free Class to Learn to Code and get Hired - A Step-by-Step Framework - https://skl.sh/3WvgSzZ\n\n\ud83e\udde0 Newsletter - https://academy.internetmadecoder.com/internet-made-club\n\nFor sponsorships: sponsorships@viralnationtalent.com\nOther: tuomas@internetmadecoder.com",
#         "otherLinks": []
#     },
#     {
#         "cname": "Agnit Shorts",
#         "curl": "https://www.youtube.com/@agnitshorts1",
#         "cdesc": "",
#         "otherLinks": []
#     },
#     {
#         "cname": "Programming with Mosh",
#         "curl": "https://www.youtube.com/@programmingwithmosh",
#         "cdesc": "I train professional software engineers that companies love to hire. \n\nMy courses: http://codewithmosh.com \n\nMy blog: http://programmingwithmosh.com\n\nConnect on social media: \n\nhttp://www.twitter.com/moshhamedani\n\nhttps://www.facebook.com/programmingwithmosh\n\n#python #javascript #chsarp",
#         "otherLinks": []
#     },
#     {
#         "cname": "Aaron Jack",
#         "curl": "https://www.youtube.com/@AaronJack",
#         "cdesc": "From Broke English Teacher to Uber Software Engineer. That was my zero to hero story.\n\nSince then, I went on to make YouTube videos and start teaching people how to code online, and make other interesting tech videos, as well as mentor people in my online program\n\nI give out free advice here, check it out:\nhttps://aaronjack.dev",
#         "otherLinks": []
#     }
# ]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.keys import Keys
import time
import json

option = Options()
option.headless = False

driver = webdriver.Firefox(options=option)

# URL of the YouTube video you want to extract comments from
video_url = "https://www.youtube.com/watch?v=7YbfDiCC-qk&ab_channel=WhiteHillMusic"

# Open the video URL
driver.get(video_url)
time.sleep(5)  # Allow time for the page to load

# Scroll down to load more comments
body = driver.find_element(By.TAG_NAME, "body")
previous_comments = 0
while True:
    body.send_keys(Keys.PAGE_DOWN)
    time.sleep(3)  # Wait for comments to load
    comment_elements = driver.find_elements(By.XPATH, '//yt-formatted-string[@id="content-text"]')
    if len(comment_elements) == previous_comments:
        break
    previous_comments = len(comment_elements)

# Extract and print the comments
for i, comment in enumerate(comment_elements, start=1):
    print(f"Comment {i}: {comment.text}")

# Extract and store comments in a list
comments = [comment.text for comment in comment_elements]

# Store comments in a JSON file
with open('youtube_comments.json', 'w', encoding='utf-8') as f:
    json.dump(comments, f, ensure_ascii=False, indent=4)

# Close the browser
driver.quit()
# Out:
# C:\Users\Najeeb\AppData\Local\Temp/ipykernel_6680/1166176992.py:9: DeprecationWarning: headless property is deprecated, instead use add_argument('-headless')
#   option.headless = False
# Comment 1: Thank you to each one of you for all the love you have given to me and Kobe  ! We love you ️
# Comment 2: This song is guide on moving on without turning bitter or hating your ex. No abuses, no toxicity, this is a survival guide️️
# Comment 3: English translation: Everyday(nit-nit) I lost my sleep over you
# You can ask the sky, the stars were my companion and witnesses
# Everyday I invested a lot in you
# Whatever you did for me/said to me, I really valued it, it meant a lot for me.
# Comment 4: This song is the food for my broken soul... Someone who wouldn't go a second without me for the past 3 years turned out to be a total stranger now... Waited for 10 months  but my new year resolution for 2022 is to move on as this song teaches without hating him... I pray may the almighty God always keep him happy n blessed
# Comment 5: one year later, and the person who introduced me to this song ain't in my life anymore yet this song still hits in all the right places
# Comment 6: I'm probably too late to watch this video but I can't resist myself from commenting and telling all the the people who are broken but being strong that you guys are the best people out there. It's just you loved more than the other person and the time was not right.
# It's alright, it's life and things happen.
# Comment 7: I lost my four legged babygirl 2 months back and have been listening to this song everyday with tears running down without my knowledge even though I don’t understand single word from this song. Thank you for such a beautiful music dedicated to the only true loving creation.
# Comment 8: She has immense power to convince us to accept unconventional music of this era.... #Sira ..miles to go #Jasleen..
# Comment 9: 3 yrs and Still my favourite
# Comment 10: My boyfriend passed away suddenly about 1 and half  year ago , when he went to Kasuli  and left me forever because of an accident there. He sing a song on my birthday, where he hugged me for the first time. I cried that time in his arms and now  I listen to this song, I feel his warmth around me. I still remember when he started crying while singing a telugu song. People leave but memories don't️
# Comment 11: She's just complete magician (musician) and composition of this song is so calm ️️
# Comment 12: I can not understand why jasleen (masterpiece singer) is so underrated in India.she deserve a lot .According to me she is best newcomer female singer in India .So plz appreciate her talent .....#soulful voice#.
# Comment 13: Last year when this song released I really enjoyed the music and Jasleen's soulful voice. But when I heard it today after more than a year, it just made me cry... Because I could feel each word of the lyrics... Thank you for making something so real and relatable...
# Comment 14: Jasleen
# I'm from the state of Acre, in Brazil and I listen to your music a lot. I like it, particularly how you create sweetly elegant melodies. Congratulations for your work.
# Comment 15: It's really hard to get rid of someone when who we love they just kill our soul  I'm here only for Jasleen Royal ️ how she presented by her soulful voice about heartbreak
# Comment 16: Your voice is different from others. It is unique, addictive. I can emotionally connect to you through your voice.️
# Comment 17: This line always hit me - “Tera gaya kuch nahi mera reha kuch nahi, gallan kara sachi nai “
# “Jo v kuch kiya tune kadara na paya”
# “Khus hai je tu ekdin me v hojana eh yaara”
# .
# Comment 18: Let's take a minute to appreciate the singing as well as acting skills of Jasleen. You are a complete package Jasleen. Lots of success on the way !!!
# Comment 19: This song helped me to heal....really used to listen it everyday and i got over that connection that didn't care about my feelings
# Comment 20: I’m commenting here but i haven’t enough words to express how much I love this track ️ and it feels superb listening during monsoon
# Comment 21: Whenever I listen to this song , it feels like - I am seeing the end of the night and the beginning of the morning. A little darkness as well as a lot of hope for light.
# Comment 22: This song so beautifully expresses that people can get over bad relationships and breakups with time back on their feet. Life goes on and that there is always light at the end of the tunnel
# Comment 23: Your voice is just like medicine for every music lover️
# Comment 24: The way video is being shot makes this song more realistic and feelable. The camera shots, visuals, direction, editing is so amazing that one can feel the emptiness of her world after being left alone by someone.its something new in punjabi music industry.
# Comment 25: Whenever am happy or sad.... this song goes with all my mood️just wonderful
# Comment 26: Losing something you never had can break you the way you never knew you could be..
# It makes you look stupid do stupid, but after a while realisation hits you and you get back on track.
# This song is like part of that realisation...
# Comment 27: I am hearing each and every song of yours really awesome u r super talented Jasleen
# Comment 28: The best scene when the dog disconnects the call!!
# Relationship with animals is more divine than relationship with humans
# Comment 29: Loads of Love Jasleen…. Still my day starts with this song and ends with it…….. I wish I could attend your concert someday….
# Comment 30: The way dog treat her, support her without utter a single word..
# Her voice is magical ️
# Comment 31: ONE THING I LOVE THE MOST ABOUT THIS SONG IS THAT LOVE WHICH YOU GET FROM YOUR FOUR LEGGED BUDDIES IS IRREPLACEABLE  AND UNCONDITIONAL
# Comment 32: This song so beautiful Expresses that people can get over bad relationship and breakups with time back on their feet .life goes on and that there is always light at the end of a tunnel
# Comment 33: Jasleen Ma'am, your voice is so soothing... It just calms down the mind for a moment... Loved this song too ️....
#
# And the relationship between a person and such lovely beings is always special... That puppy was always there for Jasleen Ma'am in this song ... Lots of love to both of you ️
# Comment 34: बेहद सुंदर !!
# Everything is so much beautiful, awesome song , lyrics , music , narration, storyline , cinematography etc.
# Wow just a complete package, It's so perfect. Mesmerizing, soothing or any word used for praising such song is less . She is creating way much beautiful songs , i just can't express , love you very much JASLEEN ROYAL.
# Comment 35: Getting your heart broken every freaking time and then coming back here to get done w the healing part, she healss w her voice , she's the healer ♡
# Comment 36: I am gonna play this video over and over until my family understands the reason why I need a dog️️
# Comment 37: Your voice and you yourself are nothing but god's gift to people like me.
# Comment 38: Amazing song each word has Deep meaning  I just loved it  specially this line 2:09
# Comment 39: The Innocence in her voice melts our hearts. ️
# Comment 40: Thank you Jasleen for this beautiful song. Stay blessed.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.keys import Keys
import time
import json

option = Options()
option.headless = False

driver = webdriver.Firefox(options=option)

# URL of the YouTube video you want to extract comments from
video_url = "https://www.youtube.com/watch?v=inTgxm6Q07w&ab_channel=%EB%AC%B8%EB%B3%B5%ED%9D%ACEatwithBoki"

# Open the video URL
driver.get(video_url)
time.sleep(5)  # Allow time for the page to load

# Partial scroll down to enable comment section
partial_scroll_height = 400  # Adjust as needed
driver.execute_script(f"window.scrollBy(0, {partial_scroll_height});")
time.sleep(3)

# Scroll down repeatedly to load more comments
scroll_pause_time = 2

# Scroll down to the end multiple times
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    
    # Wait to load page
    time.sleep(scroll_pause_time)
    
    # Attempt to load more comments by clicking the "Show more" button (if available)
    try:
        show_more_button = driver.find_element(By.XPATH, "//yt-formatted-string[contains(text(), 'Show more')]")
        show_more_button.click()
        time.sleep(scroll_pause_time)
    except:
        pass
    
    # Calculate new scroll height
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    
    # Check if scrolling to the end
    if new_height == last_height:
        break
    last_height = new_height

# Extract comment elements
comment_elements = driver.find_elements(By.CSS_SELECTOR, "#content-text")

# Extract and print the comments
for i, comment in enumerate(comment_elements, start=1):
    print(f"Comment {i}: {comment.text}")

# Extract and store comments in a list
comments = [comment.text for comment in comment_elements]

# Store comments in a JSON file
with open('youtube_comments.json', 'w', encoding='utf-8') as f:
    json.dump(comments, f, ensure_ascii=False, indent=4)

# Close the browser
driver.quit()
# Out:
# C:\Users\Najeeb\AppData\Local\Temp/ipykernel_1316/3119549455.py:9: DeprecationWarning: headless property is deprecated, instead use add_argument('-headless')
#   option.headless = False
# Comment 1: 안녕하세용 제가 요즘 치킨을 자주 먹어서 당분간 거리두기 하려고 했는데 bhc 신메뉴 마법클이 자꾸 제 눈에 보이더라구요??? 그래서 할 수 없이 시켜버렸어요
# 면도 요즘 많이 먹어서 밥 먹으려다가 마법클이 살짝 느끼하다는 후기가 있어서 불닭볶음면까지 가져와버렸다는 그런 이야기^^헤헷
# Comment 2: 이사람처럼 맛나고 깔끔하게 먹는 사람도 없는듯~^^쩝쩝소리 안내고 진짜 최고다!♡
# Comment 3: Amo os seus vídeos. Meu sonho chegar nesse nível. Quem sabe um dia
# Comment 4: Que delícia sua refeição ️️🇧🇷🇧🇷
# Comment 5: Boki has out done herself this time.This muk-bang with crispy garlic chicken,cheese balls and buldak noodles had my taste buds jumpin.
# Comment 6: 언니 한입 먹으려고 음식 뜰 때 희희 마딨게땅 이런 표정이 너무 귀여워ㅠ
# Comment 7: 식단 관리할때 이런 음식 못 먹지만
# 복희님이 대신 먹어주셔서
# 대리만족으로 최고예요
# 감사합니다
# Comment 8: 역시 복희님은 맛있게 먹는 조합을 아시는군요~!
# 나도 먹어보니 저렇게 먹으면 정말 맛있어요
# Comment 9: 나는 50대 아줌마인데 복스럽게 먹는건 복희씨가 최고인거 같아요^^
# 입맛 없을때 틀어놓고 먹으면 입안에 침이 돌아 밥한그릇 뚝딱해요~~
# Comment 10: so satisfying, I really love Korean ramyeon ahhh it looks so yummy
# Comment 11: ボキちゃんがよく食べるプルダックポックンミョンとチキンの組み合わせ好き
# Comment 12: Original flavor of Buldak noodles is my favorite! Follow by the Quattro Cheese
# Comment 13: Incredible Mukbang you eat so well, love your content, keep up the great work
# Comment 14: 맛있겠다....언니 제발 치킨이나 디저트같은거 많이해주세요♡♡
# Comment 15: A dish that makes drool really... So good ️
# Comment 16: Hello Boki, I like watching you mukbang, it seems you are really enjoying your delicious food
# Comment 17: 같은여자로서 볼매다 특히음식을 너무예쁘게복스럽게먹네
# Comment 18: It's sooo delicious! My fav is corn dog! And sooo cheesy and has sausages! Soo yummy!
# Comment 223: baskin rosbin pls
# Comment 224: why you always cut your video every time you swallow? everytime.
# Comment 225: Hi Boki!!
# Comment 226: it’s 1 am……
# Comment 227: I'm sorry, please, please do it, I don't understand Russian.
# Comment 228: Bokiiii can i get a heart?
# Comment 229: たまにくちゃくちゃする音が気になります
# Comment 230: i luv u
# Comment 231: Bat_a   뱉아
# Comment 232: 91 coment
# Comment 233: ㅉ
# Comment 234: Que fomeee
# Comment 235: 안녕 각
# Comment 236:
# Comment 237: As always cute and sweet

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.keys import Keys
import time
import json
import pandas as pd

option = Options()
option.headless = False

driver = webdriver.Firefox(options=option)

# URL of the YouTube video you want to extract comments from
video_url = "https://www.youtube.com/watch?v=B1mIMjGkYbo&ab_channel=%EB%AC%B8%EB%B3%B5%ED%9D%ACEatwithBoki"

# Open the video URL
driver.get(video_url)
time.sleep(5)  # Allow time for the page to load

# Partial scroll down to enable comment section
partial_scroll_height = 400  # Adjust as needed
driver.execute_script(f"window.scrollBy(0, {partial_scroll_height});")
time.sleep(3)

# Scroll down repeatedly to load more comments
scroll_pause_time = 2

# Scroll down to the end multiple times
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    
    # Wait to load page
    time.sleep(scroll_pause_time)
    
    # Attempt to load more comments by clicking the "Show more" button (if available)
    try:
        show_more_button = driver.find_element(By.XPATH, "//yt-formatted-string[contains(text(), 'Show more')]")
        show_more_button.click()
        time.sleep(scroll_pause_time)
    except:
        pass
    
    # Calculate new scroll height
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    
    # Check if scrolling to the end
    if new_height == last_height:
        break
    last_height = new_height

# Extract comment elements
comment_elements = driver.find_elements(By.CSS_SELECTOR, "#content-text")

# Extract comments and store in a list
comments = [comment.text for comment in comment_elements]

# Close the browser
driver.quit()

# Create a DataFrame from the comments
comments_df = pd.DataFrame({"Comment": comments})

# Display the DataFrame
print(comments_df)
# Out:
# C:\Users\Najeeb\AppData\Local\Temp/ipykernel_1316/3492378627.py:10: DeprecationWarning: headless property is deprecated, instead use add_argument('-headless')
#   option.headless = False
#                                                Comment
# 0    안녕하세용 오늘은 맥도날드 신메뉴인 진도 대파 크림치즈 크로켓버거가 너무 궁금해서 ...
# 1    I don't know how you do it Boki, but you make ...
# 2    Amo tanto ver esses vídeos, que até comecei a ...
# 3                 진짜 이렇게 깔끔하고 보기 편하게 먹는 사람 언니밖에 없어요 ..
# 4                        Que Delícia sua refeição 🇧🇷🇧🇷
# ..                                                 ...
# 353  What’s with the curtain your wearing that’s li...
# 354       could you please eat with your mouth closed?
# 355  You have very good sounds but it really is ver...
# 356  Why do you have sauces if you barely touch the...
# 357                               hhhhhhhhh biwchhiuta
#
# [358 rows x 1 columns]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.keys import Keys
import time
import json
import pandas as pd

option = Options()
option.headless = False

driver = webdriver.Firefox(options=option)

# URL of the YouTube video you want to extract comments from
video_url = "https://www.youtube.com/watch?v=B1mIMjGkYbo&ab_channel=%EB%AC%B8%EB%B3%B5%ED%9D%ACEatwithBoki"

# Open the video URL
driver.get(video_url)
time.sleep(5)  # Allow time for the page to load

# Partial scroll down to enable comment section
partial_scroll_height = 400  # Adjust as needed
driver.execute_script(f"window.scrollBy(0, {partial_scroll_height});")
time.sleep(3)

# Scroll down repeatedly to load more comments
scroll_pause_time = 2

# Scroll down to the end multiple times
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    
    # Wait to load page
    time.sleep(scroll_pause_time)
    
    # Attempt to load more comments by clicking the "Show more" button (if available)
    try:
        show_more_button = driver.find_element(By.XPATH, "//yt-formatted-string[contains(text(), 'Show more')]")
        show_more_button.click()
        time.sleep(scroll_pause_time)
    except:
        pass
    
    # Calculate new scroll height
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    
    # Check if scrolling to the end
    if new_height == last_height:
        break
    last_height = new_height

# Extract comment elements
comment_elements = driver.find_elements(By.CSS_SELECTOR, "#content-text")
like_elements = driver.find_elements(By.CSS_SELECTOR, "#vote-count-middle")

# Extract comments and likes, and store in lists
comments = [comment.text for comment in comment_elements]
likes = [like.text for like in like_elements]

# Close the browser
driver.quit()

# Create a DataFrame from the comments and likes
comments_df = pd.DataFrame({"Comment": comments, "Likes": likes})

# Display the DataFrame
print(comments_df)
# Out:
# C:\Users\Najeeb\AppData\Local\Temp/ipykernel_1316/1377582580.py:10: DeprecationWarning: headless property is deprecated, instead use add_argument('-headless')
#   option.headless = False
#                                                Comment Likes
# 0    안녕하세용 오늘은 맥도날드 신메뉴인 진도 대파 크림치즈 크로켓버거가 너무 궁금해서 ...   208
# 1    I don't know how you do it Boki, but you make ...    68
# 2    Amo tanto ver esses vídeos, que até comecei a ...    29
# 3                 진짜 이렇게 깔끔하고 보기 편하게 먹는 사람 언니밖에 없어요 ..    13
# 4                        Que Delícia sua refeição 🇧🇷🇧🇷     9
# ..                                                 ...   ...
# 353  What’s with the curtain your wearing that’s li...
# 354       could you please eat with your mouth closed?     4
# 355  You have very good sounds but it really is ver...
# 356  Why do you have sauces if you barely touch the...     1
# 357                               hhhhhhhhh biwchhiuta
#
# [358 rows x 2 columns]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.keys import Keys
import time
import json
import pandas as pd

option = Options()
option.headless = False

driver = webdriver.Firefox(options=option)

# URL of the YouTube video you want to extract comments from
video_url = "https://www.youtube.com/watch?v=B1mIMjGkYbo&ab_channel=%EB%AC%B8%EB%B3%B5%ED%9D%ACEatwithBoki"

# Open the video URL
driver.get(video_url)
time.sleep(5)  # Allow time for the page to load

# Partial scroll down to enable comment section
partial_scroll_height = 400  # Adjust as needed
driver.execute_script(f"window.scrollBy(0, {partial_scroll_height});")
time.sleep(3)

# Scroll down repeatedly to load more comments
scroll_pause_time = 2

# Scroll down to the end multiple times
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    
    # Wait to load page
    time.sleep(scroll_pause_time)
    
    # Attempt to load more comments by clicking the "Show more" button (if available)
    try:
        show_more_button = driver.find_element(By.XPATH, "//yt-formatted-string[contains(text(), 'Show more')]")
        show_more_button.click()
        time.sleep(scroll_pause_time)
    except:
        pass
    
    # Calculate new scroll height
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    
    # Check if scrolling to the end
    if new_height == last_height:
        break
    last_height = new_height

# Extract comment elements
comment_elements = driver.find_elements(By.CSS_SELECTOR, "#content-text")
like_elements = driver.find_elements(By.CSS_SELECTOR, "#vote-count-middle")

# Extract comments and likes, and store in lists
comments = [comment.text for comment in comment_elements]
likes = [like.text for like in like_elements]

# Close the browser
driver.quit()

# Create a DataFrame from the comments and likes
comments_df = pd.DataFrame({"Comment": comments, "Likes": likes})

# Display the DataFrame
print(comments_df)
# Out:
# C:\Users\Najeeb\AppData\Local\Temp/ipykernel_1316/1377582580.py:10: DeprecationWarning: headless property is deprecated, instead use add_argument('-headless')
#   option.headless = False
#                                                Comment Likes
# 0    안녕하세용 오늘은 맥도날드 신메뉴인 진도 대파 크림치즈 크로켓버거가 너무 궁금해서 ...   208
# 1    I don't know how you do it Boki, but you make ...    68
# 2    Amo tanto ver esses vídeos, que até comecei a ...    29
# 3                 진짜 이렇게 깔끔하고 보기 편하게 먹는 사람 언니밖에 없어요 ..    13
# 4                        Que Delícia sua refeição 🇧🇷🇧🇷     9
# ..                                                 ...   ...
# 353  What’s with the curtain your wearing that’s li...
# 354       could you please eat with your mouth closed?     4
# 355  You have very good sounds but it really is ver...
# 356  Why do you have sauces if you barely touch the...     1
# 357                               hhhhhhhhh biwchhiuta
#
# [358 rows x 2 columns]

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.keys import Keys
import time
import json
import pandas as pd

option = Options()
option.headless = False

driver = webdriver.Firefox(options=option)

# URL of the YouTube video you want to extract comments from
video_url = "https://www.youtube.com/watch?v=B1mIMjGkYbo&ab_channel=%EB%AC%B8%EB%B3%B5%ED%9D%ACEatwithBoki"

# Open the video URL
driver.get(video_url)
time.sleep(5)  # Allow time for the page to load

# Partial scroll down to enable comment section
partial_scroll_height = 400  # Adjust as needed
driver.execute_script(f"window.scrollBy(0, {partial_scroll_height});")
time.sleep(3)

# Scroll down repeatedly to load more comments
scroll_pause_time = 2

# Scroll down to the end multiple times
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    
    # Wait to load page
    time.sleep(scroll_pause_time)
    
    # Attempt to load more comments by clicking the "Show more" button (if available)
    try:
        show_more_button = driver.find_element(By.XPATH, "//yt-formatted-string[contains(text(), 'Show more')]")
        show_more_button.click()
        time.sleep(scroll_pause_time)
    except:
        pass
    
    # Calculate new scroll height
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    
    # Check if scrolling to the end
    if new_height == last_height:
        break
    last_height = new_height

# Extract comment elements, likes, and replies
comment_elements = driver.find_elements(By.CSS_SELECTOR, "#content-text")
like_elements = driver.find_elements(By.CSS_SELECTOR, "#vote-count-middle")
reply_elements = driver.find_elements(By.CSS_SELECTOR, "#replies")

# Extract comments, likes, and replies, and store in lists
comments = [comment.text for comment in comment_elements]
likes = [like.text for like in like_elements]
replies = [reply.text for reply in reply_elements]

# Close the browser
driver.quit()

# Create a DataFrame from the comments, likes, and replies
comments_df = pd.DataFrame({"Comment": comments, "Likes": likes, "Replies": replies})

# Display the DataFrame
comments_df
# Out:
# C:\Users\Najeeb\AppData\Local\Temp/ipykernel_1316/2750833157.py:10: DeprecationWarning: headless property is deprecated, instead use add_argument('-headless')
#   option.headless = False
#                                                Comment Likes    Replies
# 0    안녕하세용 오늘은 맥도날드 신메뉴인 진도 대파 크림치즈 크로켓버거가 너무 궁금해서 ...   208  9 replies
# 1    I don't know how you do it Boki, but you make ...    68    1 reply
# 2    Amo tanto ver esses vídeos, que até comecei a ...    29    1 reply
# 3                 진짜 이렇게 깔끔하고 보기 편하게 먹는 사람 언니밖에 없어요 ..    13
# 4                        Que Delícia sua refeição 🇧🇷🇧🇷     9
# ..                                                 ...   ...        ...
# 353  What’s with the curtain your wearing that’s li...
# 354       could you please eat with your mouth closed?     4
# 355  You have very good sounds but it really is ver...
# 356  Why do you have sauces if you barely touch the...     1
# 357                               hhhhhhhhh biwchhiuta
#
# [358 rows x 3 columns]

# %%
comments_df["Replies"].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Selenium Best Code

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.keys import Keys
import time
import json
import pandas as pd

option = Options()
option.headless = False

driver = webdriver.Firefox(options=option)

# URL of the YouTube video you want to extract comments from
video_url = "https://www.youtube.com/watch?v=918oGJFtjjw&list=RD3fenQ5UOEWc&index=4&ab_channel=ZaynVEVO"
# Open the video URL
driver.get(video_url)
time.sleep(5)  # Allow time for the page to load

# Partial scroll down to enable comment section
partial_scroll_height = 400  # Adjust as needed
driver.execute_script(f"window.scrollBy(0, {partial_scroll_height});")
time.sleep(3)

# Scroll down repeatedly to load more comments
scroll_pause_time = 2

# Scroll down to the end multiple times
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
    
    # Wait to load page
    time.sleep(scroll_pause_time)
    
    # Attempt to load more comments by clicking the "Show more" button (if available)
    try:
        show_more_button = driver.find_element(By.XPATH, "//yt-formatted-string[contains(text(), 'Show more')]")
        show_more_button.click()
        time.sleep(scroll_pause_time)
    except:
        pass
    
    # Calculate new scroll height
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    
    # Check if scrolling to the end
    if new_height == last_height:
        break
    last_height = new_height

# Extract comment elements, likes, and replies
comment_elements = driver.find_elements(By.CSS_SELECTOR, "#content-text")
like_elements = driver.find_elements(By.CSS_SELECTOR, "#vote-count-middle")
reply_elements = driver.find_elements(By.CSS_SELECTOR, "#replies")

# Extract comments, likes, and replies, and store in lists
comments = [comment.text for comment in comment_elements]
likes = [like.text for like in like_elements]
replies = [int(reply.text.split()[0]) if reply.text else 0 for reply in reply_elements]

# Close the browser
driver.quit()

# Create a DataFrame from the comments, likes, and replies
comments_df = pd.DataFrame({"Comment": comments, "Likes": likes, "Replies": replies})

# Display the DataFrame
print(comments_df)
# Out:
# C:\Users\Najeeb\AppData\Local\Temp/ipykernel_1316/1207029790.py:10: DeprecationWarning: headless property is deprecated, instead use add_argument('-headless')
#   option.headless = False
#                                                 Comment Likes  Replies
# 0                                    Only zayn forever     28        0
# 1                              I like this song so much    17        0
# 2     This song deserves a billion views\nLike if yo...    26        0
# 3     This song is just too good how it's still so l...    14        1
# 4     Finally zayn made its comeback, your fans were...    21        1
# ...                                                 ...   ...      ...
# 1409                         Old Zayn \nNew Zayn songs      2        1
# 1410                          Another song another flop     2        0
# 1411                  Zayn Malik bad worst song forever     3        0
# 1412                                      One more flop              1
# 1413                                               flop     1        0
#
# [1414 rows x 3 columns]

# %%
comments_df.head()
# Out:
#                                              Comment Likes  Replies
# 0                                 Only zayn forever     28        0
# 1                           I like this song so much    17        0
# 2  This song deserves a billion views\nLike if yo...    26        0
# 3  This song is just too good how it's still so l...    14        1
# 4  Finally zayn made its comeback, your fans were...    21        1

# %%
comments_df["Replies"].sum()
# Out:
# 1366

# %%
from googleapiclient.discovery import build
import pandas as pd

video_id = "otx0Bnru0dY"
api_key = "AIzaSyAncltA5JKsvH9PKJV3Tvz27EabFjWsYdw"

# recursive function to get all replies in a comment thread
def get_replies(comment_id, token):
    replies_response = yt_object.comments().list(part='snippet', maxResults=100, parentId=comment_id, pageToken=token).execute()

    for reply in replies_response['items']:
        all_comments.append(reply['snippet']['textDisplay'])

    if replies_response.get("nextPageToken"):
        return get_replies(comment_id, replies_response['nextPageToken'])
    else:
        return []


# recursive function to get all comments
def get_comments(youtube, video_id, next_view_token):
    global all_comments

    if len(next_view_token.strip()) == 0:
        all_comments = []

    if next_view_token == '':
        comment_list = youtube.commentThreads().list(part='snippet', maxResults=100, videoId=video_id, order='relevance').execute()
    else:
        comment_list = youtube.commentThreads().list(part='snippet', maxResults=100, videoId=video_id, order='relevance', pageToken=next_view_token).execute()

    for comment in comment_list['items']:
        all_comments.append([comment['snippet']['topLevelComment']['snippet']['textDisplay']])
        reply_count = comment['snippet']['totalReplyCount']
        all_replies = []

        if reply_count > 0:
            replies_list = youtube.comments().list(part='snippet', maxResults=100, parentId=comment['id']).execute()
            for reply in replies_list['items']:
                all_replies.append(reply['snippet']['textDisplay'])

            while "nextPageToken" in replies_list:
                token_reply = replies_list['nextPageToken']
                replies_list = youtube.comments().list(part='snippet', maxResults=100, parentId=comment['id'], pageToken=token_reply).execute()
                for reply in replies_list['items']:
                    all_replies.append(reply['snippet']['textDisplay'])

        all_comments[-1].append(all_replies)

    if "nextPageToken" in comment_list:
        return get_comments(youtube, video_id, comment_list['nextPageToken'])
    else:
        return []


all_comments = []
yt_object = build('youtube', 'v3', developerKey=api_key)

# get all comments and replies
comments = get_comments(yt_object, video_id, '')

# Create a DataFrame to store the data
data = []

for comment, replies in all_comments:
    replies_text = "\n".join(replies)
    data.append({'Comment': comment, 'Replies': replies_text})

df = pd.DataFrame(data)
df.head()
# Save the DataFrame to a CSV file
#df.to_csv('youtube_comments.csv', index=False)

# %%
# Recursive function to get all replies in a comment thread
def get_replies(comment_id, token):
    replies_response = yt_object.comments().list(part='snippet', maxResults=100, parentId=comment_id, pageToken=token).execute()

    for reply in replies_response['items']:
        all_comments.append({
            'Comment': reply['snippet']['textDisplay'],
            'Likes': reply['snippet']['likeCount']
        })

    if replies_response.get("nextPageToken"):
        return get_replies(comment_id, replies_response['nextPageToken'])
    else:
        return []


# Recursive function to get all comments
def get_comments(youtube, video_id, next_view_token):
    global all_comments

    if len(next_view_token.strip()) == 0:
        all_comments = []

    if next_view_token == '':
        comment_list = youtube.commentThreads().list(part='snippet', maxResults=100, videoId=video_id, order='relevance').execute()
    else:
        comment_list = youtube.commentThreads().list(part='snippet', maxResults=100, videoId=video_id, order='relevance', pageToken=next_view_token).execute()

    for comment in comment_list['items']:
        comment_data = {
            'Comment': comment['snippet']['topLevelComment']['snippet']['textDisplay'],
            'Likes': comment['snippet']['topLevelComment']['snippet']['likeCount']
        }
        all_comments.append(comment_data)
        reply_count = comment['snippet']['totalReplyCount']
        all_replies = []

        if reply_count > 0:
            replies_list = youtube.comments().list(part='snippet', maxResults=100, parentId=comment['id']).execute()
            for reply in replies_list['items']:
                all_replies.append({
                    'Comment': reply['snippet']['textDisplay'],
                    'Likes': reply['snippet']['likeCount']
                })

            while "nextPageToken" in replies_list:
                token_reply = replies_list['nextPageToken']
                replies_list = youtube.comments().list(part='snippet', maxResults=100, parentId=comment['id'], pageToken=token_reply).execute()
                for reply in replies_list['items']:
                    all_replies.append({
                        'Comment': reply['snippet']['textDisplay'],
                        'Likes': reply['snippet']['likeCount']
                    })

        comment_data['Replies'] = all_replies

    if "nextPageToken" in comment_list:
        return get_comments(youtube, video_id, comment_list['nextPageToken'])
    else:
        return []


all_comments = []
yt_object = build('youtube', 'v3', developerKey=api_key)

# Get all comments and replies
comments = get_comments(yt_object, video_id, '')

# Create a DataFrame to store the data
data = []

for comment_data in all_comments:
    replies = comment_data.get('Replies', [])
    replies_text = "\n".join([reply['Comment'] for reply in replies])
    data.append({
        'Comment': comment_data['Comment'],
        'Likes': comment_data['Likes'],
        'Replies': replies_text
    })

df = pd.DataFrame(data)
df.head()

# Save the DataFrame to a CSV file
# df.to_csv('youtube_comments.csv', index=False)
# Out:
#                                                                                                                                                                                                                   Comment  \
# 0                                                                                                                                                       so weird how i still know the lyrics word for word 10 years later
# 1                                                                                                                                                                       It&#39;s 2022, and I still love this song so much
# 2  I was a Senior in High School when I first heard this song. 10 years later, while being super stressed out on work (I&#39;m a teacher btw), I decided to re-listen to the songs I used to listen to when I was a teen.
# 3                        Its 2023 and i find myself listening to this song again. I just love the lyrics! Specially the part, &quot;Coz im no superman. I hope you like me as I am.&quot; I could listen to this all day💗
# 4                                                                                                                                                     11 years later and this song still gives me so much serotonin &lt;3
#
#    Likes  \
# 0    559
# 1    179
# 2    796
# 3     27
# 4     66
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Replies
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Even me as of 2023😂\nSae\nSAMMEE!\nright?? that&#39;s so crazy\nyeah the arrangements and lyrics still fresh\nsame\nRight. After a long time not hearing this, the lyrics are magically still there. I&#39;m also thrilled. ❤️\nsame\nfrfr\nsameeeee
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Still here 2023. Never will this song be old
# 2  This is my first time hearing it, and I am currently a high school senior.\n😊🎶🎶\nFirst time hearing it , and I&#39;m in senior highschool right now😀\ni was like 9 when i first heard this song, had it on my itunes. now i&#39;m revisiting it at 17\nHi ma&#39;am pwede kaba ka eye ball\n@Ace jj\nI&#39;m from Taiwan, when I was in junior high school, my English teacher used this song as apart of our course.\nHi teacher 😍\nAll we are the same. We older and life get harder and harder before. I just wanna comeback to my teenage. Good old days 😊\nStress reliever.\nMa&#39;am pwede ba ako mag enroll sa puso mo hihi, di ako si Superman, nor someone who sings Superman who is lookin good, but I can be your own Batman hehe..\nSame here\nSame here, highschool days are coming back to my mind, damn.\nHello Teacher! How you doing!
# 3
# 4

# %%
# Recursive function to get all replies in a comment thread
def get_replies(comment_id, token):
    replies_response = yt_object.comments().list(part='snippet', maxResults=100, parentId=comment_id, pageToken=token).execute()

    for reply in replies_response['items']:
        all_comments.append({
            'Comment': reply['snippet']['textDisplay'],
            'Likes': reply['snippet']['likeCount'],
            'Date': reply['snippet']['publishedAt']
        })

    if replies_response.get("nextPageToken"):
        return get_replies(comment_id, replies_response['nextPageToken'])
    else:
        return []


# Recursive function to get all comments
def get_comments(youtube, video_id, next_view_token):
    global all_comments

    if len(next_view_token.strip()) == 0:
        all_comments = []

    if next_view_token == '':
        comment_list = youtube.commentThreads().list(part='snippet', maxResults=100, videoId=video_id, order='relevance').execute()
    else:
        comment_list = youtube.commentThreads().list(part='snippet', maxResults=100, videoId=video_id, order='relevance', pageToken=next_view_token).execute()

    for comment in comment_list['items']:
        comment_data = {
            'Comment': comment['snippet']['topLevelComment']['snippet']['textDisplay'],
            'Likes': comment['snippet']['topLevelComment']['snippet']['likeCount'],
            'Date': comment['snippet']['topLevelComment']['snippet']['publishedAt']
        }
        all_comments.append(comment_data)
        reply_count = comment['snippet']['totalReplyCount']
        all_replies = []

        if reply_count > 0:
            replies_list = youtube.comments().list(part='snippet', maxResults=100, parentId=comment['id']).execute()
            for reply in replies_list['items']:
                all_replies.append({
                    'Comment': reply['snippet']['textDisplay'],
                    'Likes': reply['snippet']['likeCount'],
                    'Date': reply['snippet']['publishedAt']
                })

            while "nextPageToken" in replies_list:
                token_reply = replies_list['nextPageToken']
                replies_list = youtube.comments().list(part='snippet', maxResults=100, parentId=comment['id'], pageToken=token_reply).execute()
                for reply in replies_list['items']:
                    all_replies.append({
                        'Comment': reply['snippet']['textDisplay'],
                        'Likes': reply['snippet']['likeCount'],
                        'Date': reply['snippet']['publishedAt']
                    })

        comment_data['Replies'] = all_replies

    if "nextPageToken" in comment_list:
        return get_comments(youtube, video_id, comment_list['nextPageToken'])
    else:
        return []


all_comments = []
yt_object = build('youtube', 'v3', developerKey=api_key)

# Get all comments and replies
comments = get_comments(yt_object, video_id, '')

# Create a DataFrame to store the data
data = []

for comment_data in all_comments:
    replies = comment_data.get('Replies', [])
    replies_text = "\n".join([reply['Comment'] for reply in replies])
    data.append({
        'Comment': comment_data['Comment'],
        'Likes': comment_data['Likes'],
        'Date': comment_data['Date'],
        'Replies': replies_text
    })

df = pd.DataFrame(data)
df.head()

# Save the DataFrame to a CSV file
# df.to_csv('youtube_comments.csv', index=False)
# Out:
#                                                                                                                                                                                                                   Comment  \
# 0                                                                                                                                                       so weird how i still know the lyrics word for word 10 years later
# 1                                                                                                                                                                       It&#39;s 2022, and I still love this song so much
# 2  I was a Senior in High School when I first heard this song. 10 years later, while being super stressed out on work (I&#39;m a teacher btw), I decided to re-listen to the songs I used to listen to when I was a teen.
# 3                        Its 2023 and i find myself listening to this song again. I just love the lyrics! Specially the part, &quot;Coz im no superman. I hope you like me as I am.&quot; I could listen to this all day💗
# 4                                                                                                                                                     11 years later and this song still gives me so much serotonin &lt;3
#
#    Likes                  Date  \
# 0    559  2021-03-21T12:57:10Z
# 1    179  2022-01-09T18:04:39Z
# 2    796  2020-10-08T03:21:24Z
# 3     27  2023-03-02T01:39:49Z
# 4     66  2021-09-03T14:11:29Z
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Replies
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Even me as of 2023😂\nSae\nSAMMEE!\nright?? that&#39;s so crazy\nyeah the arrangements and lyrics still fresh\nsame\nRight. After a long time not hearing this, the lyrics are magically still there. I&#39;m also thrilled. ❤️\nsame\nfrfr\nsameeeee
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Still here 2023. Never will this song be old
# 2  This is my first time hearing it, and I am currently a high school senior.\n😊🎶🎶\nFirst time hearing it , and I&#39;m in senior highschool right now😀\ni was like 9 when i first heard this song, had it on my itunes. now i&#39;m revisiting it at 17\nHi ma&#39;am pwede kaba ka eye ball\n@Ace jj\nI&#39;m from Taiwan, when I was in junior high school, my English teacher used this song as apart of our course.\nHi teacher 😍\nAll we are the same. We older and life get harder and harder before. I just wanna comeback to my teenage. Good old days 😊\nStress reliever.\nMa&#39;am pwede ba ako mag enroll sa puso mo hihi, di ako si Superman, nor someone who sings Superman who is lookin good, but I can be your own Batman hehe..\nSame here\nSame here, highschool days are coming back to my mind, damn.\nHello Teacher! How you doing!
# 3
# 4

# %%
video_id = "9DwzBICPhdM"
api_key = "AIzaSyAncltA5JKsvH9PKJV3Tvz27EabFjWsYdw"


# Recursive function to get all replies in a comment thread
def get_replies(comment_id, token):
    replies_response = yt_object.comments().list(part='snippet', maxResults=100, parentId=comment_id, pageToken=token).execute()

    for reply in replies_response['items']:
        all_comments.append({
            'Comment': reply['snippet']['textDisplay'],
            'Likes': reply['snippet']['likeCount'],
            'Date': reply['snippet']['publishedAt']
        })

    if replies_response.get("nextPageToken"):
        return get_replies(comment_id, replies_response['nextPageToken'])
    else:
        return []


# Recursive function to get all comments
def get_comments(youtube, video_id, next_view_token):
    global all_comments

    if len(next_view_token.strip()) == 0:
        all_comments = []

    if next_view_token == '':
        comment_list = youtube.commentThreads().list(part='snippet', maxResults=100, videoId=video_id, order='relevance').execute()
    else:
        comment_list = youtube.commentThreads().list(part='snippet', maxResults=100, videoId=video_id, order='relevance', pageToken=next_view_token).execute()

    for comment in comment_list['items']:
        comment_data = {
            'Comment': comment['snippet']['topLevelComment']['snippet']['textDisplay'],
            'Likes': comment['snippet']['topLevelComment']['snippet']['likeCount'],
            'Date': comment['snippet']['topLevelComment']['snippet']['publishedAt']
        }
        all_comments.append(comment_data)
        reply_count = comment['snippet']['totalReplyCount']
        all_replies = []

        if reply_count > 0:
            replies_list = youtube.comments().list(part='snippet', maxResults=100, parentId=comment['id']).execute()
            for reply in replies_list['items']:
                all_replies.append({
                    'Comment': reply['snippet']['textDisplay'],
                    'Likes': reply['snippet']['likeCount'],
                    'Date': reply['snippet']['publishedAt']
                })

            while "nextPageToken" in replies_list:
                token_reply = replies_list['nextPageToken']
                replies_list = youtube.comments().list(part='snippet', maxResults=100, parentId=comment['id'], pageToken=token_reply).execute()
                for reply in replies_list['items']:
                    all_replies.append({
                        'Comment': reply['snippet']['textDisplay'],
                        'Likes': reply['snippet']['likeCount'],
                        'Date': reply['snippet']['publishedAt']
                    })

        comment_data['Replies'] = all_replies
        comment_data['NumReplies'] = reply_count  # New line to add the number of replies to comment_data

    if "nextPageToken" in comment_list:
        return get_comments(youtube, video_id, comment_list['nextPageToken'])
    else:
        return []


# Print video details
video_response = yt_object.videos().list(part='snippet,statistics', id=video_id).execute()
video_title = video_response['items'][0]['snippet']['title']
video_likes = int(video_response['items'][0]['statistics']['likeCount'])
video_dislikes = video_response['items'][0]['statistics'].get('dislikeCount', 'N/A')

print("Video Title:", video_title)
print("Total Likes:", video_likes)
print("Total Dislikes:", video_dislikes)


# Get all comments and replies
comments = get_comments(yt_object, video_id, '')

# Create a DataFrame to store the data
data = []

for comment_data in all_comments:
    replies = comment_data.get('Replies', [])
    replies_text = "\n".join([reply['Comment'] for reply in replies])
    data.append({
        'Comment': comment_data['Comment'],
        'Likes': comment_data['Likes'],
        'Date': comment_data['Date'],
        'Replies': replies_text,
        'NumReplies': comment_data['NumReplies']  # New line to add the number of replies to the DataFrame
    })

df = pd.DataFrame(data)
df.head()

# Save the DataFrame to a CSV file
# df.to_csv('youtube_comments.csv', index=False)
# Out:
# Video Title: BTS (방탄소년단) 'Not Today' Official MV
# Total Likes: 9750467
# Total Dislikes: N/A
#                                              Comment  Likes  \
# 0  rap line literally nailed their parts..i reall...    862
# 1  Vamos armys fazer essa obra de arte chegar nós...     14
# 2         Las canciones de BTS siempre serán épicos.     13
# 3  Tremenda canción,vamos por más ejército,a dele...      6
# 4  WOW, отличное, великолепное исполнение песни&q...      8
#
#                    Date                                            Replies  \
# 0  2023-06-18T13:17:34Z  @Kerry Holland they are struggling in their so...
# 1  2023-08-12T18:18:42Z
# 2  2023-07-30T10:12:09Z
# 3  2023-08-05T22:33:37Z
# 4  2023-08-14T05:17:06Z                                      Remove Em0jis
#
#    NumReplies
# 0           7
# 1           0
# 2           0
# 3           0
# 4           1

# %%
df.shape
# Out:
# (1449, 5)

# %%
df.drop(["Replies"],axis=1,inplace = True)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18708/35383358.py in <module>
# ----> 1 df.drop(["Replies"],axis=1,inplace = True)
#       2 df.head()
#
# c:\Users\Najeeb\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\Najeeb\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4952                 weight  1.0     0.8
#    4953         """
# -> 4954         return super().drop(
#    4955             labels=labels,
#    4956             axis=axis,
#
# c:\Users\Najeeb\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# c:\Users\Najeeb\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# c:\Users\Najeeb\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6642         if mask.any():
#    6643             if errors != "ignore":
# -> 6644                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645             indexer = indexer[~mask]
#    6646         return self.delete(indexer)
#
# KeyError: "['Replies'] not found in axis"

# %%
df.shape
# Out:
# (1502, 6)

# %%
# Assuming you already have the DataFrame 'df' and a column named 'Date'

# Convert 'Date' column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Extract 'Date' and 'Time' components
df['Formatted Date'] = df['Date'].dt.strftime('%d-%m-%Y')
df['Formatted Time'] = df['Date'].dt.strftime('%H:%M:%S')

# Display the updated DataFrame
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 1     am currently crying so hard right now. This is seriously the most beautiful, well put together story ever. I can’t believe how magical it was <a href="https://www.youtube.com/watch?v=kJQP7kiw5Fk&amp;t=0m02s">0:02</a>. That part truly made me shed a tear. And especially at <a href="https://www.youtube.com/watch?v=kJQP7kiw5Fk&amp;t=0m12s">0:12</a> that part was just so truly heart touching words can not describe the series of emotions I felt. I absolutely loved the climax it had insanely excellent detail. Oh and we can’t forget the conclusion. The conclusion was the greatest and saddest conclusion I have ever seen better than any of the books I have read. Thank you so much for creating this absolute masterpiece. This is essentially the most important masterpiece of film history. It is a tragedy that this, it can’t be called a film, but a transcendent emotional experience, will be inaccessible for most. It beautifully encapsulates the human struggle to its basics; suffering, pleasure, faith, despair. It connects with the characters within the viewers, individuals suppressed within our own subconscious. It stays vibrant, fresh, and revolutionizes the art of storytelling and filmmaking while making a damn of statement on what it means to be human. Entertaining, gripping, and simply exhilarating. This might be the most impactful piece of art I’ve come across in my life, and I’m definitely coming back to it in the near future to study it more deeply. this is an absolute masterpiece , I was brought to tears listening to this and seeing the coems go whirly swirly in a circle countless times. it absolutely moved my soul , and I don&#39;t think I can ever be the same. this bacon has changed my entire mental state , I am now at peace with who I am and what I will be doing later in my life. i have forgiven all my enemies and now I am a man of a pacifist life. I will move on , gotta move on , as the song says. the coems is so inspirational , it shares it vast wisdom with all of us , and we are all so lucky that it would bestow it&#39;s great words with us. we are all children on coems . hail coems. hail coems . The Dancing coems, rotating in one direction with this music... This made me tear up. How could such a bacon do such a thing? I&#39;m struck by awe by this masterpiece. Especially when the coems Dancing, showing its lightly salt covered yellow skin. I can hear the crunch just from here, and so as the beautiful sound of the coems scraping the dark, smooth velvet floor.  The flavor, music and everything can be heard, tasted, seen and felt from a screen. You can really hear the breaths between the music artist, empathizing her love for this rotating coems. Truly what I call modern art. This was the most legendary performance by any piece of coems I have ever watched. The acting was top tier and very life changing. This is one of the greatest work from a piece of coems I have ever seen especially on <a href="https://www.youtube.com/watch?v=kJQP7kiw5Fk&amp;t=0m01s">0:01</a>.I am currently crying so hard right now. This is seriously the most beautiful, well put together story ever. I can’t believe how magical it was <a href="https://www.youtube.com/watch?v=kJQP7kiw5Fk&amp;t=0m03s">0:03</a>. That part truly made me shed a tear. And especially at <a href="https://www.youtube.com/watch?v=kJQP7kiw5Fk&amp;t=0m02s">0:02</a> that part was just so truly heart touching words can not describe the series of emotions I felt. I absolutely loved the climax it had insanely excellent detail. Oh and we can’t forget the conclusion. The conclusion was the greatest and saddest conclusion I have ever seen better than any of the books I have read. Thank you so much for creating this absolute masterpiece. This is essentially the most important masterpiece of film history. It is a tragedy that this, it can’t be called a film, but a transcendent emotional experience, will be inaccessible for most. It beautifully encapsulates the human struggle to its basics; ...
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ...
# 1497                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 1498                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 1499                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 1500                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# ...
# 1499                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 1500                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 1501                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
#
#       NumReplies Formatted Date Formatted Time
# 0            496     27-03-2021       09:25:21
# 1              0     15-08-2023       05:58:23
# 2              1     12-08-2023       19:12:39
# 3              4     13-08-2023       00:01:31
# 4              0     08-08-2023       02:07:31
# ...          ...            ...            ...
# 1497           0     13-08-2023       18:29:34
# 1498           0     14-08-2023       05:02:36
# 1499           0     14-08-2023       18:45:18
# 1500           1     14-08-2023       20:20:53
# 1501           0     12-08-2023       15:45:44
#
# [1502 rows x 7 columns]

# %%
# Make a copy of the original 'Date' column
df['Original Date'] = df['Date'].copy()

# Convert 'Date' column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Extract 'Date' and 'Time' components
df['Formatted Date'] = df['Date'].dt.strftime('%d-%m-%Y')
df['Formatted Time'] = df['Date'].dt.strftime('%H:%M:%S')

# Display the updated DataFrame
df
# Out:
#                                                                                                                                                                                                                      Comment  \
# 0                                                                                                                                                          so weird how i still know the lyrics word for word 10 years later
# 1                                                                                                                                                                          It&#39;s 2022, and I still love this song so much
# 2     I was a Senior in High School when I first heard this song. 10 years later, while being super stressed out on work (I&#39;m a teacher btw), I decided to re-listen to the songs I used to listen to when I was a teen.
# 3                           Its 2023 and i find myself listening to this song again. I just love the lyrics! Specially the part, &quot;Coz im no superman. I hope you like me as I am.&quot; I could listen to this all day💗
# 4                                                                                                                                                        11 years later and this song still gives me so much serotonin &lt;3
# ...                                                                                                                                                                                                                      ...
# 1340                                                                                                       MGA BOBO: SINO NAG PUNTA DITO DAHIL KAY RENEJAY?<br><br>AKO:DI MAINTINDIHAN KUNG BAKIT INEROCOMENDA TO NI YOUTUBE
# 1341                                                                                                                                                                                                    Did not care for it.
# 1342                                                                                                                       Puro kayo renejay, eh ako dati ko pa to pinapakinggan nung di pa sikat yang mga pinagsasabi niyo.
# Recursive function to get all replies in a comment thread
def get_replies(comment_id, token):
    replies_response = yt_object.comments().list(part='snippet', maxResults=100, parentId=comment_id, pageToken=token).execute()
    replies = []

    for reply in replies_response['items']:
        reply_data = {
            'Comment': reply['snippet']['textDisplay'],
            'Likes': reply['snippet']['likeCount'],
            'Date': reply['snippet']['publishedAt']
        }
        replies.append(reply_data)

    if replies_response.get("nextPageToken"):
        return replies + get_replies(comment_id, replies_response['nextPageToken'])
    else:
        return replies

# Recursive function to get all comments
def get_comments(youtube, video_id, next_view_token):
    if len(next_view_token.strip()) == 0:
        all_comments = []

    if next_view_token == '':
        comment_list = youtube.commentThreads().list(part='snippet', maxResults=100, videoId=video_id, order='relevance').execute()
    else:
        comment_list = youtube.commentThreads().list(part='snippet', maxResults=100, videoId=video_id, order='relevance', pageToken=next_view_token).execute()

    all_comments = []

    for comment in comment_list['items']:
        comment_data = {
            'Comment': comment['snippet']['topLevelComment']['snippet']['textDisplay'],
            'Likes': comment['snippet']['topLevelComment']['snippet']['likeCount'],
            'Date': comment['snippet']['topLevelComment']['snippet']['publishedAt']
        }
        reply_count = comment['snippet']['totalReplyCount']
        comment_data['Replies'] = get_replies(comment['id'], token=None)
        comment_data['NumReplies'] = reply_count
        all_comments.append(comment_data)

    if "nextPageToken" in comment_list:
        return all_comments + get_comments(youtube, video_id, comment_list['nextPageToken'])
    else:
        return all_comments

# Print video details
video_response = yt_object.videos().list(part='snippet,statistics', id=video_id).execute()
video_title = video_response['items'][0]['snippet']['title']
video_likes = int(video_response['items'][0]['statistics']['likeCount'])
video_dislikes = video_response['items'][0]['statistics'].get('dislikeCount', 'N/A')

print("Video Title:", video_title)
print("Total Likes:", video_likes)
print("Total Dislikes:", video_dislikes)

# Get all comments and replies
comments = get_comments(yt_object, video_id, '')

# Create a DataFrame to store the data
data = []

for comment_data in comments:
    replies = comment_data.get('Replies', [])
    replies_text = "\n".join([reply['Comment'] for reply in replies])

    utc_datetime = datetime.strptime(comment_data['Date'], '%Y-%m-%dT%H:%M:%SZ')
    ist_datetime = utc_datetime.replace(tzinfo=timezone.utc).astimezone(timezone(timedelta(hours=5, minutes=30)))

    data.append({
        'Comment': comment_data['Comment'],
        'Likes': comment_data['Likes'],
        'Date': ist_datetime.strftime('%d-%m-%Y'),
        'Time': ist_datetime.strftime('%H:%M:%S'),
        'Replies': replies_text,
        'NumReplies': comment_data['NumReplies']
    })

df = pd.DataFrame(data)
df.head()

# Save the DataFrame to a CSV file
# df.to_csv('youtube_comments.csv', index=False)
# Out:
# Video Title: Joe Brooks - Superman
# Total Likes: 264348
# Total Dislikes: N/A
#                                                                                                                                                                                                                   Comment  \
# 0                                                                                                                                                       so weird how i still know the lyrics word for word 10 years later
# 1                                                                                                                                                                       It&#39;s 2022, and I still love this song so much
# 2  I was a Senior in High School when I first heard this song. 10 years later, while being super stressed out on work (I&#39;m a teacher btw), I decided to re-listen to the songs I used to listen to when I was a teen.
# 3                        Its 2023 and i find myself listening to this song again. I just love the lyrics! Specially the part, &quot;Coz im no superman. I hope you like me as I am.&quot; I could listen to this all day💗
# 4                                                                                                                                                     11 years later and this song still gives me so much serotonin &lt;3
#
#    Likes        Date      Time  \
# 0    560  21-03-2021  18:27:10
# 1    180  09-01-2022  23:34:39
# 2    796  08-10-2020  08:51:24
# 3     27  02-03-2023  07:09:49
# 4     67  03-09-2021  19:41:29
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Replies  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                i was just thinking the same thing!\nEven me as of 2023😂\nSae\nSAMMEE!\nright?? that&#39;s so crazy\nyeah the arrangements and lyrics still fresh\nsame\nRight. After a long time not hearing this, the lyrics are magically still there. I&#39;m also thrilled. ❤️\nsame\nfrfr\nsameeeee
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Still here 2023. Never will this song be old
# 2  This is my first time hearing it, and I am currently a high school senior.\n😊🎶🎶\nFirst time hearing it , and I&#39;m in senior highschool right now😀\ni was like 9 when i first heard this song, had it on my itunes. now i&#39;m revisiting it at 17\nHi ma&#39;am pwede kaba ka eye ball\n@Ace jj\nI&#39;m from Taiwan, when I was in junior high school, my English teacher used this song as apart of our course.\nHi teacher 😍\nAll we are the same. We older and life get harder and harder before. I just wanna comeback to my teenage. Good old days 😊\nStress reliever.\nMa&#39;am pwede ba ako mag enroll sa puso mo hihi, di ako si Superman, nor someone who sings Superman who is lookin good, but I can be your own Batman hehe..\nSame here\nSame here, highschool days are coming back to my mind, damn.\nHello Teacher! How you doing!
# 3
# 4
#
#    NumReplies
# 0          11
# 1           1
# 2          14
# 3           0
# 4           0

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
def sentiment_Vader(text):
    over_all_polarity = sid.polarity_scores(text)
    if over_all_polarity['compound'] >= 0.05:
        return "positive"
    elif over_all_polarity['compound'] <= -0.05:
        return "negative"
    else:
        return "neutral"


sid = SentimentIntensityAnalyzer()

#data_file = pd.read_csv('E:/MS Thesis/Dataset MS Thesis/ALL DATA SQL/All Data For all Wave/first_wave.csv')

df['sentiment_vader'] = df['Comment'].apply(lambda x: sentiment_Vader(x))

df
# Out:
#                                                                                                                                                                                                                      Comment  \
# 0                                                                                                                                                          so weird how i still know the lyrics word for word 10 years later
# 1                                                                                                                                                                          It&#39;s 2022, and I still love this song so much
# 2     I was a Senior in High School when I first heard this song. 10 years later, while being super stressed out on work (I&#39;m a teacher btw), I decided to re-listen to the songs I used to listen to when I was a teen.
# 3                           Its 2023 and i find myself listening to this song again. I just love the lyrics! Specially the part, &quot;Coz im no superman. I hope you like me as I am.&quot; I could listen to this all day💗
# 4                                                                                                                                                        11 years later and this song still gives me so much serotonin &lt;3
# ...                                                                                                                                                                                                                      ...
# 1340                                                                                                       MGA BOBO: SINO NAG PUNTA DITO DAHIL KAY RENEJAY?<br><br>AKO:DI MAINTINDIHAN KUNG BAKIT INEROCOMENDA TO NI YOUTUBE
# 1341                                                                                                                                                                                                    Did not care for it.
# 1342                                                                                                                       Puro kayo renejay, eh ako dati ko pa to pinapakinggan nung di pa sikat yang mga pinagsasabi niyo.
# 1343                                                                                                                                                                                       Lagunya jelek banget, gak bermutu
# 1344                                                                                                                                                                                                                  Shite.
#
#       Likes                  Date  \
# 0       559  2021-03-21T12:57:10Z
# 1       179  2022-01-09T18:04:39Z
# 2       796  2020-10-08T03:21:24Z
# 3        27  2023-03-02T01:39:49Z
# 4        66  2021-09-03T14:11:29Z
# ...     ...                   ...
# 1340      1  2020-05-14T13:27:59Z
# 1341      0  2020-09-25T01:46:29Z
# 1342      0  2020-05-28T09:51:34Z
# 1343      0  2021-03-18T06:41:53Z
# 1344      0  2021-05-18T21:12:15Z
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Replies  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Even me as of 2023😂\nSae\nSAMMEE!\nright?? that&#39;s so crazy\nyeah the arrangements and lyrics still fresh\nsame\nRight. After a long time not hearing this, the lyrics are magically still there. I&#39;m also thrilled. ❤️\nsame\nfrfr\nsameeeee
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Still here 2023. Never will this song be old
# 2     This is my first time hearing it, and I am currently a high school senior.\n😊🎶🎶\nFirst time hearing it , and I&#39;m in senior highschool right now😀\ni was like 9 when i first heard this song, had it on my itunes. now i&#39;m revisiting it at 17\nHi ma&#39;am pwede kaba ka eye ball\n@Ace jj\nI&#39;m from Taiwan, when I was in junior high school, my English teacher used this song as apart of our course.\nHi teacher 😍\nAll we are the same. We older and life get harder and harder before. I just wanna comeback to my teenage. Good old days 😊\nStress reliever.\nMa&#39;am pwede ba ako mag enroll sa puso mo hihi, di ako si Superman, nor someone who sings Superman who is lookin good, but I can be your own Batman hehe..\nSame here\nSame here, highschool days are coming back to my mind, damn.\nHello Teacher! How you doing!
# 3
# 4
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 1340                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              First time?
# 1341
# 1342                                                                                                                                                                                                                                                                                                                                                                                             @Alice Genesis Mendoza Talamante tsaka nakakasura na yung puro sabi &quot;sino nandito dahil kila renejay at samantha&quot; like what the fuck? Nihindi ko nga kilala mga yan pero sinearch ko mga nobody lang pala mga alaga ni dogie\nNakakainis na nagiging uso lang yung kantang di popular dahil sa isang &quot;renejey&quot; kuno Like wtf?\nKaya nga mga parang tanga eh. Kala nila kilala ng lahat ng tao yan. Dito lang naman sikat sa pinas yan eh
# 1343
# 1344
#
#       NumReplies sentiment_vader
# 0             10        negative
# 1              1        positive
# 2             14        positive
# 3              0        positive
# 4              0         neutral
# ...          ...             ...
# 1340           1        negative
# 1341           0        negative
# 1342           3         neutral
# 1343           0         neutral
# 1344           0         neutral
#
# [1345 rows x 6 columns]

# %%
# Create a DataFrame to store the data
data = []

total_likes = 0
total_dislikes = 0

for comment_data in all_comments:
    replies = comment_data.get('Replies', [])
    replies_text = "\n".join([reply['Comment'] for reply in replies])
    data.append({
        'Comment': comment_data['Comment'],
        'Likes': comment_data['Likes'],
        'Date': comment_data['Date'],
        'Replies': replies_text,
        'NumReplies': comment_data['NumReplies']
    })

    total_likes += comment_data['Likes']

# ... (previous code)

# Print video details
video_response = yt_object.videos().list(part='snippet,statistics', id=video_id).execute()
video_title = video_response['items'][0]['snippet']['title']
video_likes = int(video_response['items'][0]['statistics']['likeCount'])
video_dislikes = video_response['items'][0]['statistics'].get('dislikeCount', 'N/A')

print("Video Title:", video_title)
print("Total Likes:", video_likes)
print("Total Dislikes:", video_dislikes)

# ... (rest of the code)
# Out:
# Video Title: Joe Brooks - Superman
# Total Likes: 264347
# Total Dislikes: N/A
